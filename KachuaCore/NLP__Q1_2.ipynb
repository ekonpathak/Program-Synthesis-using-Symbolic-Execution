# %%
#1

file = open('/Users/lucifer/Downloads/data/hi/hii.txt', 'r')
ll = []
t_dict = {}
str = file.read()
tokens = str.split()
ustr = set(tokens)
for words in ustr :
    t_dict[words] = tokens.count(words)
    print('Frequency of ', words , 'is :', tokens.count(words))
file.close()
# def freq(str):
 
#     # break the string into list of words
#     str_list = str.split()
 
#     # gives set of unique words
#     unique_words = set(str_list)
     
#     for words in unique_words :
#         print('Frequency of ', words , 'is :', str_list.count(words))


t_dict = dict( sorted(t_dict.items(), key=operator.itemgetter(1),reverse=True))
t_dict
# Out:
# Frequency of  यह is : 1
# Frequency of  आम is : 1
# Frequency of  सार्वजनिक is : 1
# Frequency of  आर्थिक is : 1
# Frequency of  दुनिया is : 1
# Frequency of  मिल is : 1
# Frequency of  कि is : 3
# Frequency of  टी is : 2
# Frequency of  निष्पक्षता is : 1
# Frequency of  मोदी is : 1
# Frequency of  विनायक is : 1
# Frequency of  इस्तेमाल is : 1
# Frequency of  तरह is : 1
# Frequency of  न्याय is : 1
# Frequency of  जाए is : 1
# Frequency of  पास is : 1
# Frequency of  इस is : 3
# Frequency of  बनाया is : 1
# Frequency of  मौजूद is : 1
# Frequency of  बस is : 1
# Frequency of  वाले is : 1
# Frequency of  डीसीएचएल is : 1
# Frequency of  व्यवहार्यता is : 1
# Frequency of  लाया is : 1
# Frequency of  वित्त is : 1
# Frequency of  की is : 3
# Frequency of  नेता is : 2
# Frequency of  कुमार is : 1
# Frequency of  समग्र is : 1
# Frequency of  सचिव is : 1
# Frequency of  पहले is : 1
# Frequency of  अधिक is : 1
# Frequency of  सभी is : 1
# Frequency of  आखिरी is : 1
# ...

# %%
#1
f = open('/Users/lucifer/Downloads/data/hi/hii.txt', 'r')
l1 = []
l2 = []

hi = ['क' ,' ख' , 'ग' ,' घ' , 'ड',' च' , 'छ' ,' ज' ,' झ' , 'ञ' ,'ट' , 'ठ' , 'ड ', 'ढ' , 'ण' ,'त' ,' थ' , 'द' , 'ध' , 'न' ,'प' , 'फ' , 'ब' , 'भ' , 'म' ,'य' , 'र' , 'ल' , 'व', 'श' , 'ष' , 'स' , 'ह' , 'क्ष','त्र' ,'ज']
#he = [' ऀ',' ँ',' ं','ः', 'ऺ','ऻ',' ़' , 'ा','ि', 'ी',' ु',' ू',' ृ',' ॄ',' ॅ',' ॆ',' े',' ै','ॉ','ॊ','ो','ौ','ॎ','ॏ']
he = ["ा", "ि", "ी", "ु", "ू", "े", "ो", "ै", "ौ", "ृ", "ॄ", "ॉ", "ं"]
hx = ['अ'  , 'आ' , 'इ' , 'ई' , 'उ'  ,'ऊ' ,' ए' , 'ऐ' , 'ओ' , 'औ' , 'अं' , 'अः' , 'ऋ','अ'  , 'आ' , 'इ' , 'ई' , 'उ'  ,'ऊ' ,' ए' , 'ऐ' , 'ओ' , 'औ' , 'अं' , 'अः' , 'ऋ']      
ma = {
     'ं':'न्',
    'ः': 'अः',
    'ा':'आ',
    'ि':'इ',
    'ी':'ई',
   'ु':'उ',
    'ू':'ऊ',
    'ृ':'ऋ',
     'े':'ए',
     'ै':'ऐ',
    'ो':'ओ',
    'ौ':'औ',
    ' ': 'अ',
    ' ': 'अ'
    
}

#word="कल्पना"
# for i in word:
#     print(i)
while (1): 
    ch = f.read(1)
    if not ch:
        
        break
    if ch == ' ':
        k = []
        for i in l1:
            if i in hx :
                k.append(i)
            elif i in he  :
                x = k.pop()
                k.append(ma[i])
            elif i in hi:
                g = i + chr(2381)
                k.append(g)
                k.append('अ')
            elif i =="्":    
                k.pop()
            else:
                k.append(i)
                
                
        l2.append(k)
        l1.clear()
    else:
        l1.append(ch)
f.close()
i = len(l2)
j = 0
while j < i:
    print(f"CHARACTERS IN {tokens[j]} ARE {l2[j]} ")
    j = j + 1
# Out:
# CHARACTERS IN कछुआ ARE ['क्', 'अ', 'छ्', 'उ', 'आ']
# CHARACTERS IN कछुआ ARE ['क्', 'अ', 'छ्', 'उ', 'आ']
# CHARACTERS IN आवेदन ARE ['आ', 'व्', 'ए', 'द्', 'अ', 'न्', 'अ']
# CHARACTERS IN कल्पना ARE ['क्', 'अ', 'ल्', 'प्', 'अ', 'न्', 'आ']
# CHARACTERS IN आवेदन ARE ['आ', 'व्', 'ए', 'द्', 'अ', 'न्', 'अ']
# CHARACTERS IN करने ARE ['क्', 'अ', 'र्', 'अ', 'न्', 'ए']
# CHARACTERS IN की ARE ['क्', 'ई']
# CHARACTERS IN आखिरी ARE ['आ', 'इ', 'र्', 'ई']
# CHARACTERS IN तारीख ARE ['त्', 'आ', 'र्', 'ई', 'ख']
# CHARACTERS IN 31 ARE ['3', '1']
# CHARACTERS IN जनवरी ARE ['ज्', 'अ', 'न्', 'अ', 'व्', 'अ', 'र्', 'ई']
# CHARACTERS IN 2020 ARE ['2', '0', '2', '0']
# CHARACTERS IN है ARE ['ह्', 'ऐ']
# CHARACTERS IN इतनी ARE ['इ', 'त्', 'अ', 'न्', 'ई']
# CHARACTERS IN दुआ ARE ['द्', 'उ', 'आ']
# CHARACTERS IN कर ARE ['क्', 'अ', 'र्', 'अ']
# CHARACTERS IN दो ARE ['द्', 'ओ']
# CHARACTERS IN हमारे ARE ['ह्', 'अ', 'म्', 'आ', 'र्', 'ए']
# CHARACTERS IN लिए ARE ['ल्', 'इ', 'ए']
# CHARACTERS IN कि ARE ['क्', 'इ']
# ...

# %%
#2

f1 = open('/Users/lucifer/Downloads/data/hi/hii.txt', 'r')
l11 = []
l22 = []
l33 = []
while (1): 
    ch = f1.read(1)
    if not ch:        
        break
    if ch == ' ':
        k = []
        for i in l11:
            if i in hx :
                k.append(i)
            elif i in he  :
                x = k.pop()
                y = x + i
                k.append(y)
            elif i in hi:
                if len(l33) != 0:
                    x = l33.pop()
                    y = x + chr(2381)
                    z = y + i
                    k.append(z)
                else:
                    k.append(i)
                 
            elif i == "्" :    
                l33.append(k.pop())
            else:
                k.append(i)
                
                
        l22.append(k)
        l11.clear()
    else:
        l11.append(ch)
f1.close()
p = len(l22)
q = 0
while q < p:
    print(f"SYLLABLES IN {tokens[q]} ARE {l22[q]} ")
    q = q + 1
l22
# Out:
# SYLLABLES IN कछुआ ARE ['क', 'छु', 'आ']
# SYLLABLES IN कछुआ ARE ['क', 'छु', 'आ']
# SYLLABLES IN आवेदन ARE ['आ', 'वे', 'द', 'न']
# SYLLABLES IN कल्पना ARE ['क', 'ल्प', 'ना']
# SYLLABLES IN आवेदन ARE ['आ', 'वे', 'द', 'न']
# SYLLABLES IN करने ARE ['क', 'र', 'ने']
# SYLLABLES IN की ARE ['की']
# SYLLABLES IN आखिरी ARE ['आ', 'खि', 'री']
# SYLLABLES IN तारीख ARE ['ता', 'री', 'ख']
# SYLLABLES IN 31 ARE ['3', '1']
# SYLLABLES IN जनवरी ARE ['ज', 'न', 'व', 'री']
# SYLLABLES IN 2020 ARE ['2', '0', '2', '0']
# SYLLABLES IN है ARE ['है']
# SYLLABLES IN इतनी ARE ['इ', 'त', 'नी']
# SYLLABLES IN दुआ ARE ['दु', 'आ']
# SYLLABLES IN कर ARE ['क', 'र']
# SYLLABLES IN दो ARE ['दो']
# SYLLABLES IN हमारे ARE ['ह', 'मा', 'रे']
# SYLLABLES IN लिए ARE ['लि', 'ए']
# SYLLABLES IN कि ARE ['कि']
# SYLLABLES IN जितना ARE ['जि', 'त', 'ना']
# SYLLABLES IN प्यार ARE ['प्या', 'र']
# SYLLABLES IN दुनिया ARE ['दु', 'नि', 'या']
# SYLLABLES IN ने ARE ['ने']
# SYLLABLES IN आपको ARE ['आ', 'प', 'को']
# ...

# %%
import operator
j = []
for i in l22:
    k = len (i)
    j.append ( k )   
syldict = {}
h = len(l22)
i = 0
while (i < h):
    
    syldict [tokens[i]] =  j[i]
    
    print(f"NUMBER OF SYLLABLES IN {tokens[i]} IS  {j[i]} ")
    
    i = i + 1
s_dict_syl = dict( sorted(syldict.items(), key=operator.itemgetter(1),reverse=True))
s_dict_syl
# Out:
# NUMBER OF SYLLABLES IN कछुआ IS  3
# NUMBER OF SYLLABLES IN कछुआ IS  3
# NUMBER OF SYLLABLES IN आवेदन IS  4
# NUMBER OF SYLLABLES IN कल्पना IS  3
# NUMBER OF SYLLABLES IN आवेदन IS  4
# NUMBER OF SYLLABLES IN करने IS  3
# NUMBER OF SYLLABLES IN की IS  1
# NUMBER OF SYLLABLES IN आखिरी IS  3
# NUMBER OF SYLLABLES IN तारीख IS  3
# NUMBER OF SYLLABLES IN 31 IS  2
# NUMBER OF SYLLABLES IN जनवरी IS  4
# NUMBER OF SYLLABLES IN 2020 IS  4
# NUMBER OF SYLLABLES IN है IS  1
# NUMBER OF SYLLABLES IN इतनी IS  3
# NUMBER OF SYLLABLES IN दुआ IS  2
# NUMBER OF SYLLABLES IN कर IS  2
# NUMBER OF SYLLABLES IN दो IS  1
# NUMBER OF SYLLABLES IN हमारे IS  3
# NUMBER OF SYLLABLES IN लिए IS  2
# NUMBER OF SYLLABLES IN कि IS  1
# NUMBER OF SYLLABLES IN जितना IS  3
# NUMBER OF SYLLABLES IN प्यार IS  2
# NUMBER OF SYLLABLES IN दुनिया IS  3
# NUMBER OF SYLLABLES IN ने IS  1
# NUMBER OF SYLLABLES IN आपको IS  3
# NUMBER OF SYLLABLES IN दिया IS  2
# NUMBER OF SYLLABLES IN है IS  1
# NUMBER OF SYLLABLES IN बस IS  2
# ...

# %%
n = []
for i in l2:
    k = len (i)
    n.append ( k )   

chardict = {}    
m = len(l22)
d = 0
while (d < m):
    
    chardict [tokens[d]] =  n[d]
    
    print(f"NUMBER OF CHARACTERS IN {tokens[d]} IS {n[d]} ")
     
    d = d + 1
s_dict_char = dict( sorted(chardict.items(), key=operator.itemgetter(1),reverse=True))
s_dict_char
# Out:
# NUMBER OF CHARACTERS IN कछुआ IS 5
# NUMBER OF CHARACTERS IN कछुआ IS 5
# NUMBER OF CHARACTERS IN आवेदन IS 7
# NUMBER OF CHARACTERS IN कल्पना IS 7
# NUMBER OF CHARACTERS IN आवेदन IS 7
# NUMBER OF CHARACTERS IN करने IS 6
# NUMBER OF CHARACTERS IN की IS 2
# NUMBER OF CHARACTERS IN आखिरी IS 4
# NUMBER OF CHARACTERS IN तारीख IS 5
# NUMBER OF CHARACTERS IN 31 IS 2
# NUMBER OF CHARACTERS IN जनवरी IS 8
# NUMBER OF CHARACTERS IN 2020 IS 4
# NUMBER OF CHARACTERS IN है IS 2
# NUMBER OF CHARACTERS IN इतनी IS 5
# NUMBER OF CHARACTERS IN दुआ IS 3
# NUMBER OF CHARACTERS IN कर IS 4
# NUMBER OF CHARACTERS IN दो IS 2
# NUMBER OF CHARACTERS IN हमारे IS 6
# NUMBER OF CHARACTERS IN लिए IS 3
# NUMBER OF CHARACTERS IN कि IS 2
# NUMBER OF CHARACTERS IN जितना IS 6
# NUMBER OF CHARACTERS IN प्यार IS 5
# NUMBER OF CHARACTERS IN दुनिया IS 6
# NUMBER OF CHARACTERS IN ने IS 2
# NUMBER OF CHARACTERS IN आपको IS 5
# NUMBER OF CHARACTERS IN दिया IS 4
# NUMBER OF CHARACTERS IN है IS 2
# NUMBER OF CHARACTERS IN बस IS 4
# ...

# %%
import collections
import nltk
l=list(nltk.bigrams(tokens))
f=collections.Counter(l)
print(f)
# Out:
# Counter({('है', 'कि'): 2, ('चेयरमैन', 'टी'): 2, ('कछुआ', 'कछुआ'): 1, ('कछुआ', 'आवेदन'): 1, ('आवेदन', 'कल्पना'): 1, ('कल्पना', 'आवेदन'): 1, ('आवेदन', 'करने'): 1, ('करने', 'की'): 1, ('की', 'आखिरी'): 1, ('आखिरी', 'तारीख'): 1, ('तारीख', '31'): 1, ('31', 'जनवरी'): 1, ('जनवरी', '2020'): 1, ('2020', 'है'): 1, ('है', 'इतनी'): 1, ('इतनी', 'दुआ'): 1, ('दुआ', 'कर'): 1, ('कर', 'दो'): 1, ('दो', 'हमारे'): 1, ('हमारे', 'लिए'): 1, ('लिए', 'कि'): 1, ('कि', 'जितना'): 1, ('जितना', 'प्यार'): 1, ('प्यार', 'दुनिया'): 1, ('दुनिया', 'ने'): 1, ('ने', 'आपको'): 1, ('आपको', 'दिया'): 1, ('दिया', 'है'): 1, ('है', 'बस'): 1, ('बस', 'उतना'): 1, ('उतना', 'ही'): 1, ('ही', 'हमें'): 1, ('हमें', 'भी'): 1, ('भी', 'मिल'): 1, ('मिल', 'जाए'): 1, ('जाए', 'मोदी'): 1, ('मोदी', 'सरकार'): 1, ('सरकार', 'के'): 1, ('के', 'पहले'): 1, ('पहले', 'कार्यकाल'): 1, ('कार्यकाल', 'में'): 1, ('में', 'भी'): 1, ('भी', 'तीन'): 1, ('तीन', 'तलाक'): 1, ('तलाक', 'को'): 1, ('को', 'लेकर'): 1, ('लेकर', 'बिल'): 1, ('बिल', 'लाया'): 1, ('लाया', 'गया'): 1, 
# ...
